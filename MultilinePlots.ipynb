# %% [markdown]
# ## Multiline Plots

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(10)
plt.plot(x, x**2)
plt.plot(x, x**3)
plt.plot(x, x*2)
plt.plot(x, 2**x)
plt.show()

# %%
plt.plot(x, x**2, x, x**3, x, x*2, x, 2**x)
plt.show()

# %%
x = np.array([[1, 2, 6, 3], [4, 5, 3, 2]])
plt.plot(x)
plt.show()

# %%
data = np.random.randn(2, 10)
print(data)
plt.plot(data[0], data[1])
plt.show()
# Out:
# [[ 0.46915215 -0.34951242  0.36967063  1.93781552 -0.04968222  0.88436167
#    1.02066363  1.73780737  0.9368104  -0.54523712]
#  [ 1.61811628 -0.39608994 -0.3666893   1.16009074  0.69299462  1.71209324
#   -0.60808437 -0.46162339  0.5716392  -0.24872692]]
